# %%
# Folium
import folium
from folium.plugins import MarkerCluster, HeatMap
import numpy as np

# %%
latitude, longitude = 40.70897880773851,-73.94260564135125

# %% [markdown]
# # Basic Map

# %%
map = folium.Map(location=[latitude, longitude])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9adc65fdc1c1187620b3d97b77beb17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9adc65fdc1c1187620b3d97b77beb17 = L.map(
#                 &quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot;,
#                 {
#                     center: [40.70897880773851, -73.94260564135125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed85ec8fdfcafef0b98ca8d29f28c460 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9adc65fdc1c1187620b3d97b77beb17);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Marker on Map

# %%
# Add a marker to the map
folium.Marker(location=[latitude, longitude], popup='Marker Popup').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9adc65fdc1c1187620b3d97b77beb17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9adc65fdc1c1187620b3d97b77beb17 = L.map(
#                 &quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot;,
#                 {
#                     center: [40.70897880773851, -73.94260564135125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed85ec8fdfcafef0b98ca8d29f28c460 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9adc65fdc1c1187620b3d97b77beb17);
#
#
#             var marker_4626a2bcac4915c3368e1351679904b5 = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_a9adc65fdc1c1187620b3d97b77beb17);
#
#
#         var popup_de1a152402f47f0977975dc4db5d9b73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d3c685f62b6e4d63b8664d3ab0c3d1a = $(`&lt;div id=&quot;html_7d3c685f62b6e4d63b8664d3ab0c3d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker Popup&lt;/div&gt;`)[0];
#                 popup_de1a152402f47f0977975dc4db5d9b73.setContent(html_7d3c685f62b6e4d63b8664d3ab0c3d1a);
#
#
#
#         marker_4626a2bcac4915c3368e1351679904b5.bindPopup(popup_de1a152402f47f0977975dc4db5d9b73)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Marker Cluster

# %%
# Generate random data for markers
marker_data = np.random.normal(size=(100, 2), loc=[latitude, longitude])

# Create a MarkerCluster
marker_cluster = MarkerCluster().add_to(map)

# Add markers to the cluster
for loc in marker_data:
    folium.Marker(location=loc).add_to(marker_cluster)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9adc65fdc1c1187620b3d97b77beb17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9adc65fdc1c1187620b3d97b77beb17 = L.map(
#                 &quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot;,
#                 {
#                     center: [40.70897880773851, -73.94260564135125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed85ec8fdfcafef0b98ca8d29f28c460 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9adc65fdc1c1187620b3d97b77beb17);
#
#
#             var marker_4626a2bcac4915c3368e1351679904b5 = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_a9adc65fdc1c1187620b3d97b77beb17);
#
#
#         var popup_de1a152402f47f0977975dc4db5d9b73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d3c685f62b6e4d63b8664d3ab0c3d1a = $(`&lt;div id=&quot;html_7d3c685f62b6e4d63b8664d3ab0c3d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker Popup&lt;/div&gt;`)[0];
#                 popup_de1a152402f47f0977975dc4db5d9b73.setContent(html_7d3c685f62b6e4d63b8664d3ab0c3d1a);
#
#
#
#         marker_4626a2bcac4915c3368e1351679904b5.bindPopup(popup_de1a152402f47f0977975dc4db5d9b73)
#         ;
#
#
#
#
#             var marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d = L.markerClusterGroup(
#                 {}
#             );
#             map_a9adc65fdc1c1187620b3d97b77beb17.addLayer(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_10664ae7780fd242411b583d94335750 = L.marker(
#                 [40.52106428140284, -71.81322146684502],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_65024612786a7db9e3b1579db8fde26d = L.marker(
#                 [40.767792317794246, -72.45277900001301],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_2faee1c59ed26ecc7ab4931508c6455a = L.marker(
#                 [41.82908825701814, -74.21318948634797],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_1cc46492ededbab25550c9975ba0cd6b = L.marker(
#                 [40.872806521891206, -74.44167313153903],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_7423acd081b91d70f548a629378273ee = L.marker(
#                 [41.025749817029066, -72.74223815180045],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_9e013f5ca1ee919672ed8cedee3c7721 = L.marker(
#                 [40.096458539989364, -73.8015675533845],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_ae8b79a29dc8ad7b7238285df5919ecc = L.marker(
#                 [41.48771922652663, -72.15263054422698],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_6fda055f9213fd7f26071c7a4408688a = L.marker(
#                 [41.84450522958988, -75.10101425995481],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_cbf7796d2d6cc4d4b4758dd9d1cbc6dd = L.marker(
#                 [41.2925063029793, -72.52533255010339],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_ce550a05fa69f0b96c8b77c4fcf89702 = L.marker(
#                 [40.988517530345135, -75.34662688316953],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_6a39bbacbcb352789add37e8ec6071e1 = L.marker(
#                 [39.52156851482027, -74.24207743593064],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_6ee3fad41d49cc7315e829ff75910e2d = L.

# %% [markdown]
# # Heatmap

# %%
# Generate random heatmap data
heatmap_data = np.random.normal(size=(100, 2), loc=[latitude, longitude])

# Create a HeatMap layer
HeatMap(heatmap_data).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9adc65fdc1c1187620b3d97b77beb17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9adc65fdc1c1187620b3d97b77beb17 = L.map(
#                 &quot;map_a9adc65fdc1c1187620b3d97b77beb17&quot;,
#                 {
#                     center: [40.70897880773851, -73.94260564135125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed85ec8fdfcafef0b98ca8d29f28c460 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9adc65fdc1c1187620b3d97b77beb17);
#
#
#             var marker_4626a2bcac4915c3368e1351679904b5 = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_a9adc65fdc1c1187620b3d97b77beb17);
#
#
#         var popup_de1a152402f47f0977975dc4db5d9b73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d3c685f62b6e4d63b8664d3ab0c3d1a = $(`&lt;div id=&quot;html_7d3c685f62b6e4d63b8664d3ab0c3d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker Popup&lt;/div&gt;`)[0];
#                 popup_de1a152402f47f0977975dc4db5d9b73.setContent(html_7d3c685f62b6e4d63b8664d3ab0c3d1a);
#
#
#
#         marker_4626a2bcac4915c3368e1351679904b5.bindPopup(popup_de1a152402f47f0977975dc4db5d9b73)
#         ;
#
#
#
#
#             var marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d = L.markerClusterGroup(
#                 {}
#             );
#             map_a9adc65fdc1c1187620b3d97b77beb17.addLayer(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_10664ae7780fd242411b583d94335750 = L.marker(
#                 [40.52106428140284, -71.81322146684502],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_65024612786a7db9e3b1579db8fde26d = L.marker(
#                 [40.767792317794246, -72.45277900001301],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_2faee1c59ed26ecc7ab4931508c6455a = L.marker(
#                 [41.82908825701814, -74.21318948634797],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_1cc46492ededbab25550c9975ba0cd6b = L.marker(
#                 [40.872806521891206, -74.44167313153903],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_7423acd081b91d70f548a629378273ee = L.marker(
#                 [41.025749817029066, -72.74223815180045],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_9e013f5ca1ee919672ed8cedee3c7721 = L.marker(
#                 [40.096458539989364, -73.8015675533845],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_ae8b79a29dc8ad7b7238285df5919ecc = L.marker(
#                 [41.48771922652663, -72.15263054422698],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_6fda055f9213fd7f26071c7a4408688a = L.marker(
#                 [41.84450522958988, -75.10101425995481],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_cbf7796d2d6cc4d4b4758dd9d1cbc6dd = L.marker(
#                 [41.2925063029793, -72.52533255010339],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_ce550a05fa69f0b96c8b77c4fcf89702 = L.marker(
#                 [40.988517530345135, -75.34662688316953],
#                 {}
#             ).addTo(marker_cluster_fb1c4e7b622abf983c0cad59c9cf1a1d);
#
#
#             var marker_6a39bbacbcb352789add37e8ec6071e1 = L.marker(
#                 [39.52156851482027, -74.24207743593064],

# %% [markdown]
# # Polygons and GeoJSON

# %%
# Coordinates for the Empire State Building
empire_state_building_coordinates = [
    [-73.985428, 40.748817],  # Top-left
    [-73.985428, 40.748424],  # Bottom-left
    [-73.984722, 40.748424],  # Bottom-right
    [-73.984722, 40.748817],  # Top-right
    [-73.985428, 40.748817]   # Top-left (closing the polygon)
]

# Create a Folium map centered at the Empire State Building
map_center = [40.748620, -73.985071]  # Centered at the Empire State Building
map = folium.Map(location=map_center, zoom_start=17)

# Create a GeoJSON polygon for the Empire State Building
empire_state_building_polygon = {
    "type": "Polygon",
    "coordinates": [empire_state_building_coordinates]
}

# Add the GeoJSON polygon to the map
folium.GeoJson(empire_state_building_polygon).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_829f9ddfe9f598b00ab7168dbb3379a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_829f9ddfe9f598b00ab7168dbb3379a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_829f9ddfe9f598b00ab7168dbb3379a4 = L.map(
#                 &quot;map_829f9ddfe9f598b00ab7168dbb3379a4&quot;,
#                 {
#                     center: [40.74862, -73.985071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f69c60e9a14a66443c471aa8cf324ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#
#         function geo_json_091ddaf48accbc923f77146d181d791d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_091ddaf48accbc923f77146d181d791d = L.geoJson(null, {
#                 onEachFeature: geo_json_091ddaf48accbc923f77146d181d791d_onEachFeature,
#
#         });
#
#         function geo_json_091ddaf48accbc923f77146d181d791d_add (data) {
#             geo_json_091ddaf48accbc923f77146d181d791d
#                 .addData(data)
#                 .addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#         }
#             geo_json_091ddaf48accbc923f77146d181d791d_add({&quot;coordinates&quot;: [[[-73.985428, 40.748817], [-73.985428, 40.748424], [-73.984722, 40.748424], [-73.984722, 40.748817], [-73.985428, 40.748817]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Popup Windows

# %%
# Add a marker with a customized popup
popup_text = '<b>Custom Popup</b><br>Latitude: {}<br>Longitude: {}'.format(latitude, longitude)
folium.Marker(location=[latitude, longitude], popup=popup_text, tooltip='Click me!').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_829f9ddfe9f598b00ab7168dbb3379a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_829f9ddfe9f598b00ab7168dbb3379a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_829f9ddfe9f598b00ab7168dbb3379a4 = L.map(
#                 &quot;map_829f9ddfe9f598b00ab7168dbb3379a4&quot;,
#                 {
#                     center: [40.74862, -73.985071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f69c60e9a14a66443c471aa8cf324ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#
#         function geo_json_091ddaf48accbc923f77146d181d791d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_091ddaf48accbc923f77146d181d791d = L.geoJson(null, {
#                 onEachFeature: geo_json_091ddaf48accbc923f77146d181d791d_onEachFeature,
#
#         });
#
#         function geo_json_091ddaf48accbc923f77146d181d791d_add (data) {
#             geo_json_091ddaf48accbc923f77146d181d791d
#                 .addData(data)
#                 .addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#         }
#             geo_json_091ddaf48accbc923f77146d181d791d_add({&quot;coordinates&quot;: [[[-73.985428, 40.748817], [-73.985428, 40.748424], [-73.984722, 40.748424], [-73.984722, 40.748817], [-73.985428, 40.748817]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             var marker_bd64fec1df10d1e617c92ea1896ed46b = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#         var popup_46028705e27c041b5ee2befa540096c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5bf8061338f4cec8d65b24b1b05a8e4 = $(`&lt;div id=&quot;html_e5bf8061338f4cec8d65b24b1b05a8e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Custom Popup&lt;/b&gt;&lt;br&gt;Latitude: 40.70897880773851&lt;br&gt;Longitude: -73.94260564135125&lt;/div&gt;`)[0];
#                 popup_46028705e27c041b5ee2befa540096c3.setContent(html_e5bf8061338f4cec8d65b24b1b05a8e4);
#
#
#
#         marker_bd64fec1df10d1e617c92ea1896ed46b.bindPopup(popup_46028705e27c041b5ee2befa540096c3)
#         ;
#
#
#
#
#             marker_bd64fec1df10d1e617c92ea1896ed46b.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_60a732b0c7ffa306ceb2d57231973b99 = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#         var popup_d8eb0c4168f6d731b85017efbf855ec4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c4667fd09a8d34ccedfd5dd4f308992 = $(`&lt;div id=&quot;html_9c4667fd09a8d34ccedfd5dd4f308992&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Custom Popup&lt;/b&gt;&lt;br&gt;Latitude: 40.70897880773851&lt;br&gt;Longitude: -73.94260564135125&lt;/div&gt;`)[0];
#                 popup_d8eb0c4168f6d731b85017efbf855ec4.setContent(html_9c4667fd09a8d34ccedfd5dd4f308992);
#
#
#
#         marker_60a732b0c7ffa306ceb2d57231973b99.bindPopup(popup_d8eb0c4168f6d731b85017efbf855ec4)
#         ;
#
#
#
#
#             marker_60a732b0c7ffa306ceb2d57231973b99.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_de5e664a87eb532922106fa845df4214 = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#         var popup_2f8e885f4c4f80b90752ff2cd42c12eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ee8bf3a7ff06a30ad8e88d625c4843b = $(`&lt;div id=&quot;html_0ee8bf3a7ff06a30ad8e88d625c4843b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Custom Popup&lt;/b&gt;&lt;br&gt;Latitude: 40.70897880773851&lt;br&gt;Longitude: -73.94260564135125&lt;/div&gt;`)[0];
#                 popup_2f8e885f4c4f80b90752ff2cd42c12eb.setContent(html_0ee8bf3a7ff06a30ad8e88d625c4843b);
#
#
#
#         marker_de5e664a87eb532922106fa845df4214.bindPopup(popup_2f8e885f4c4f80b90752ff2cd42c12eb)
#         ;
#
#
#
#
#             marker_de5e664a87eb532922106fa845df4214.bindTooltip(
#                 `&lt;div

# %% [markdown]
# # Layer Control

# %%
# Create two layers with markers
layer1 = folium.FeatureGroup(name='Layer 1')
folium.Marker(location=[40.74852287758696, -73.98582464982313], popup='Marker 1').add_to(layer1)
folium.Marker(location=[40.74852286271184, -73.98353006596405], popup='Marker 2').add_to(layer1)

layer2 = folium.FeatureGroup(name='Layer 2')
folium.Marker(location=[40.74337799196688, -73.98762770861886], popup='Marker 3').add_to(layer2)
folium.Marker(location=[40.74276510463482, -73.98583586088724], popup='Marker 4').add_to(layer2)

# Add layers to the map and add LayerControl
layer1.add_to(map)
layer2.add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_829f9ddfe9f598b00ab7168dbb3379a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_829f9ddfe9f598b00ab7168dbb3379a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_829f9ddfe9f598b00ab7168dbb3379a4 = L.map(
#                 &quot;map_829f9ddfe9f598b00ab7168dbb3379a4&quot;,
#                 {
#                     center: [40.74862, -73.985071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f69c60e9a14a66443c471aa8cf324ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#
#         function geo_json_091ddaf48accbc923f77146d181d791d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_091ddaf48accbc923f77146d181d791d = L.geoJson(null, {
#                 onEachFeature: geo_json_091ddaf48accbc923f77146d181d791d_onEachFeature,
#
#         });
#
#         function geo_json_091ddaf48accbc923f77146d181d791d_add (data) {
#             geo_json_091ddaf48accbc923f77146d181d791d
#                 .addData(data)
#                 .addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#         }
#             geo_json_091ddaf48accbc923f77146d181d791d_add({&quot;coordinates&quot;: [[[-73.985428, 40.748817], [-73.985428, 40.748424], [-73.984722, 40.748424], [-73.984722, 40.748817], [-73.985428, 40.748817]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             var marker_bd64fec1df10d1e617c92ea1896ed46b = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#         var popup_46028705e27c041b5ee2befa540096c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5bf8061338f4cec8d65b24b1b05a8e4 = $(`&lt;div id=&quot;html_e5bf8061338f4cec8d65b24b1b05a8e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Custom Popup&lt;/b&gt;&lt;br&gt;Latitude: 40.70897880773851&lt;br&gt;Longitude: -73.94260564135125&lt;/div&gt;`)[0];
#                 popup_46028705e27c041b5ee2befa540096c3.setContent(html_e5bf8061338f4cec8d65b24b1b05a8e4);
#
#
#
#         marker_bd64fec1df10d1e617c92ea1896ed46b.bindPopup(popup_46028705e27c041b5ee2befa540096c3)
#         ;
#
#
#
#
#             marker_bd64fec1df10d1e617c92ea1896ed46b.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_60a732b0c7ffa306ceb2d57231973b99 = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#         var popup_d8eb0c4168f6d731b85017efbf855ec4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c4667fd09a8d34ccedfd5dd4f308992 = $(`&lt;div id=&quot;html_9c4667fd09a8d34ccedfd5dd4f308992&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Custom Popup&lt;/b&gt;&lt;br&gt;Latitude: 40.70897880773851&lt;br&gt;Longitude: -73.94260564135125&lt;/div&gt;`)[0];
#                 popup_d8eb0c4168f6d731b85017efbf855ec4.setContent(html_9c4667fd09a8d34ccedfd5dd4f308992);
#
#
#
#         marker_60a732b0c7ffa306ceb2d57231973b99.bindPopup(popup_d8eb0c4168f6d731b85017efbf855ec4)
#         ;
#
#
#
#
#             marker_60a732b0c7ffa306ceb2d57231973b99.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_de5e664a87eb532922106fa845df4214 = L.marker(
#                 [40.70897880773851, -73.94260564135125],
#                 {}
#             ).addTo(map_829f9ddfe9f598b00ab7168dbb3379a4);
#
#
#         var popup_2f8e885f4c4f80b90752ff2cd42c12eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ee8bf3a7ff06a30ad8e88d625c4843b = $(`&lt;div id=&quot;html_0ee8bf3a7ff06a30ad8e88d625c4843b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Custom Popup&lt;/b&gt;&lt;br&gt;Latitude: 40.70897880773851&lt;br&gt;Longitude: -73.94260564135125&lt;/div&gt;`)[0];
#                 popup_2f8e885f4c4f80b90752ff2cd42c12eb.setContent(html_0ee8bf3a7ff06a30ad8e88d625c4843b);
#
#
#
#         marker_de5e664a87eb532922106fa845df4214.bindPopup(popup_2f8e885f4c4f80b90752ff2cd42c12eb)
#         ;
#
#
#
#
#             marker_de5e664a87eb532922106fa845df4214.bindTooltip(
#                 `&lt;div

# %% [markdown]
# # Save as HTML

# %%
map.save("del.html")
